# %% [markdown]
# ## Creating a Linear Regression Model

# %% [markdown]
# ### Discovery
#
# Welcome new data analyst contractor, to Ethical Oil Inc. Whilst on your generous and extremely interesting 30 second induction, your IT systems have been fully set up, tested and everything is working perfectly. <br><br>
# As your first task, you have been tasked with trying to determine if there is a linear relationship between the cost of oil and the S&P 500 valuation. You will use a linear regression model to establish if any relationship exists and if so, how oil prices are impacted by stock market fluctuations. Data has already been sourced by the ever efficient and humble management team.

# %% [markdown]
# First we will import the required modules. They are:
# - pandas
# - seaborn
# - statsmodels.api
# - sklearn.model_selection - train_test_split

# %%
# Import required modules
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from sklearn.model_selection import train_test_split

# %% [markdown]
# ---
# ### Data preparation
# Import the stocks dataset. Set the index column as the "Date". Remember to validate the import has worked.

# %%
# Import the first dataset and set the date as the index
stock_df = pd.read_csv("all_stocks_5yr.csv", index_col="Date", parse_dates=True, date_format="%d%m/%Y")
#stock_df = pd.read_csv("all_stocks_5yr.csv")
stock_df
# Out:
#                   Open       Close         Low        High
# Date
# 01/02/2013   58.135082   58.106483   57.600095   58.656064
# 01/03/2013   59.430461   59.531515   58.986414   59.924352
# 01/04/2013   60.261989   60.294833   59.653234   60.829809
# 01/05/2013   63.189973   63.284582   62.681440   63.854413
# 01/06/2013   62.080930   61.994978   61.373427   62.672076
# ...                ...         ...         ...         ...
# 01/10/2017  102.854219  102.908070  102.036919  103.656867
# 01/11/2017  103.862055  104.014336  103.020190  104.836911
# 01/12/2017  106.639923  106.488189  105.682850  107.456124
# 01/01/2018  111.661892  111.778353  110.634552  112.707958
# 01/02/2018  109.520721  109.226602  107.589618  111.584564
#
# [61 rows x 4 columns]

# %% [markdown]
# Import the oil dataset, set the index column as "date". Remember to validate teh import has worked.

# %%
# Import the second dataset and set the date as the index
oil_df = pd.read_csv("crude-oil-price.csv", index_col="date", parse_dates=True, date_format="%d%m/%Y")
oil_df
# Out:
#               price  percentChange  change
# date
# 01/03/1983  29.2700            NaN     NaN
# 01/04/1983  30.6300          4.646  1.3600
# 01/05/1983  30.2500         -1.241 -0.3800
# 01/06/1983  31.3800          3.736  1.1300
# 01/07/1983  32.0000          1.976  0.6200
# ...             ...            ...     ...
# 01/05/2025  60.7900          4.432  2.5800
# 01/06/2025  65.1100          7.106  4.3200
# 01/07/2025  69.2600          6.374  4.1500
# 01/08/2025  64.0100         -7.580 -5.2500
# 01/09/2025  63.7496         -0.407 -0.2604
#
# [511 rows x 3 columns]

# %% [markdown]
# Create a new dataframe - restricting the oil data to rows (dates) that overlap between the stock and oil datasets only.

# %%
# Restrict the dataframe to just the dates that we want (match the stock dates)
rest_oil = oil_df.loc["01/02/2013":"01/02/2018"]
rest_oil
# Out:
#             price  percentChange  change
# date
# 01/02/2013  92.05         -5.580   -5.44
# 01/03/2013  97.23          5.627    5.18
# 01/04/2013  93.46         -3.877   -3.77
# 01/05/2013  91.97         -1.594   -1.49
# 01/06/2013  96.56          4.991    4.59
# ...           ...            ...     ...
# 01/10/2017  54.38          5.245    2.71
# 01/11/2017  57.40          5.554    3.02
# 01/12/2017  60.42          5.261    3.02
# 01/01/2018  64.73          7.133    4.31
# 01/02/2018  61.64         -4.774   -3.09
#
# [61 rows x 3 columns]

# %% [markdown]
# Combine the two datasets together. This hasn't not been demonstrated previously, so you will need to research how to do this, but that's why you get paid the big bucks! You should end up with 61 rows of data, and all columns, from both dataframes in the same dataframe. Use an inner join. <br><br>
# <b>Hint</b>: keep it simple, and use a single line of code.

# %%
# Combine both dataframes together using an inner join. 
join_df = rest_oil.join(stock_df, how="inner")
join_df
# Out:
#             price  percentChange  change        Open       Close         Low  \
# 01/02/2013  92.05         -5.580   -5.44   58.135082   58.106483   57.600095
# 01/03/2013  97.23          5.627    5.18   59.430461   59.531515   58.986414
# 01/04/2013  93.46         -3.877   -3.77   60.261989   60.294833   59.653234
# 01/05/2013  91.97         -1.594   -1.49   63.189973   63.284582   62.681440
# 01/06/2013  96.56          4.991    4.59   62.080930   61.994978   61.373427
# ...           ...            ...     ...         ...         ...         ...
# 01/10/2017  54.38          5.245    2.71  102.854219  102.908070  102.036919
# 01/11/2017  57.40          5.554    3.02  103.862055  104.014336  103.020190
# 01/12/2017  60.42          5.261    3.02  106.639923  106.488189  105.682850
# 01/01/2018  64.73          7.133    4.31  111.661892  111.778353  110.634552
# 01/02/2018  61.64         -4.774   -3.09  109.520721  109.226602  107.589618
#
#                   High
# 01/02/2013   58.656064
# 01/03/2013   59.924352
# 01/04/2013   60.829809
# 01/05/2013   63.854413
# 01/06/2013   62.672076
# ...                ...
# 01/10/2017  103.656867
# 01/11/2017  104.836911
# 01/12/2017  107.456124
# 01/01/2018  112.707958
# 01/02/2018  111.584564
#
# [61 rows x 7 columns]

# %% [markdown]
# ---
# ### Model planning
# You will now need to understand which variables have a relationship from the prepared data. Identifying the strength and direction of the relationships will help you to build a useful model, within the remit of the task.

# %% [markdown]
# Create a correlation matrix, to establish which variables you wish to use. We will only use 1 indepednent and 1 depedant variable for this model.

# %%
# Use price as dependent and select another appropriate variable to predict the output. 
join_corr = join_df.corr()
sns.heatmap(join_corr, annot=True, cmap="Blues")
# Out:
# <Axes: >

# %% [markdown]
# Create a Regplot/Scatterplot to demonstrate the relationship between our dependent and independent variable.

# %%
# Check the relationship between the selected variables
sns.regplot(x = "Close",
            y = "price",
            data = join_df)
# Out:
# <Axes: xlabel='Close', ylabel='price'>

# %% [markdown]
# ---
# ### Building the model
# Split the data into training and test datasets - include the random_state argument:<br>
# random_state = 25

# %%
# Split the data into train and test samples
train, test = train_test_split(join_df,random_state=25)

# %% [markdown]
# Set both the independent variable and dependent variable - remember to check they are set correctly. Don't forget to add a constant to your independent variables.

# %%
# Set the dependent variable and validate
dep = train["price"]
dep.head()
# Out:
# 01/05/2015     60.30
# 01/10/2017     54.38
# 01/08/2013    107.65
# 01/02/2016     33.75
# 01/01/2014     97.49
# Name: price, dtype: float64

# %%
# Set the independent variable and validate
ind = train["Close"]
ind.head()
# Out:
# 01/05/2015     85.705089
# 01/10/2017    102.908070
# 01/08/2013     64.504099
# 01/02/2016     76.983138
# 01/01/2014     71.825667
# Name: Close, dtype: float64

# %%
# Remember to add the constant 
ind = sm.add_constant(ind)
ind.head()
# Out:
#             const       Close
# 01/05/2015    1.0   85.705089
# 01/10/2017    1.0  102.908070
# 01/08/2013    1.0   64.504099
# 01/02/2016    1.0   76.983138
# 01/01/2014    1.0   71.825667

# %% [markdown]
# Now generate the model along with a summary output.

# %%
# Fit the model and produce the summary
model = sm.OLS(dep,ind).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.498
# Model:                            OLS   Adj. R-squared:                  0.487
# Method:                 Least Squares   F-statistic:                     42.71
# Date:                Wed, 10 Sep 2025   Prob (F-statistic):           6.08e-08
# Time:                        10:47:01   Log-Likelihood:                -189.39
# No. Observations:                  45   AIC:                             382.8
# Df Residuals:                      43   BIC:                             386.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        175.7521     16.942     10.374      0.000     141.585     209.919
# Close         -1.3205      0.202     -6.535      0.000      -1.728      -0.913
# ==============================================================================
# Omnibus:                        0.024   Durbin-Watson:                   2.058
# Prob(Omnibus):                  0.988   Jarque-Bera (JB):                0.203
# Skew:                          -0.010   Prob(JB):                        0.903
# Kurtosis:                       2.671   Cond. No.                         572.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ---
# ### Communicating the results.
# You will now analyse the model and communicate the results. What do the following outputs tell you about the model
#
# - R-Squared:
# - F-Statistic:
# - Prob (F-Statistic):
# - P-Value:
# - Coefficient:
# - Constant:

# %% [markdown]
# Now lets test the model output - remember to add a constant to your test data.

# %%
# Set the test sample independent variable and use the model to predict the variable, using the test dataset 
test_ind = test[["Close"]]
test_ind = sm.add_constant(test_ind)
output = model.predict(test_ind)

# %% [markdown]
# Finally, add a predicted column to your test dataset, where you have your prediction shown, alongside your actual values for your dependent variable.

# %%
# Add the predicted values to our test dataframe to compare actual with predicted. 
test["predicted"] = output
test[["price","Close","predicted"]]
# Out:
#              price       Close  predicted
# 01/02/2014  102.59   72.859147  79.543491
# 01/03/2014  101.58   74.899410  76.849376
# 01/04/2014   99.74   74.578316  77.273373
# 01/09/2014   91.16   79.037900  71.384607
# 01/09/2013  102.33   65.744264  88.938510
# 01/01/2016   33.62   77.898386  72.889307
# 01/04/2016   45.92   84.534876  64.125993
# 01/07/2015   47.12   85.227152  63.211861
# 01/07/2016   41.60   87.679289  59.973877
# 01/09/2017   51.67  100.133291  43.528690
# 01/01/2018   64.73  111.778353  28.151686
# 01/08/2016   44.70   89.098273  58.100145
# 01/02/2013   92.05   58.106483  99.024002
# 01/11/2017   57.40  104.014336  38.403869
# 01/08/2015   49.20   84.442031  64.248593
# 01/12/2015   37.04   83.568774  65.401705

# %% [markdown]
# Now you have genereated some predictions with the test data, explain the output by way of the formula Y = mX + C

# %% [markdown]
# ---
# ### Stretch task
# Create a new dataframe with some example data, and generate some predictions using your model.
#
# ---

# %%
# Create a new dataframe

# %%
# Generate  predictions

# %%
# Generate results in the dataframe, based on new dataset.

# %% [markdown]
# ---
# ### Operationalise
# In the real world, this is where you would draft a report, deliver briefings, implement with automation on production level servers, produce technical documentation and build this into your BAU process. This being a fictional company, the ever grateful management have granted you paid leave for all your hard work and have volunteered to take on this burden themselves. Congratulations and well done!
